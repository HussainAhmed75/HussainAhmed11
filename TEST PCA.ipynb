# %% [markdown]
# <a href="https://colab.research.google.com/github/HussainAhmed75/HussainAhmed11/blob/main/TEST%20PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import pandas as pd
# Example dataset
df = pd.DataFrame({
    'Height':[170,165,180,175,160],
    'Weight':[70,65,80,75,55],
    'Age':[22,25,30,28,19]
})
# Scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)
# PCA
pca = PCA(n_components=2)
pca_output = pca.fit_transform(X_scaled)
pca_output[:5]
# Out:
# array([[-3.30185000e-01, -6.23081001e-01],
#        [-6.55389872e-01,  5.18157548e-01],
#        [ 2.31104660e+00,  7.38573054e-04],
#        [ 1.27483392e+00,  1.04014025e-01],
#        [-2.60030565e+00,  1.70854852e-04]])

# %%
print(X_scaled[:5])
# Out:
# [[ 0.          0.11624764 -0.70530981]
#  [-0.70710678 -0.46499055  0.05037927]
#  [ 1.41421356  1.27872403  1.30986108]
#  [ 0.70710678  0.69748583  0.80606835]
#  [-1.41421356 -1.62746694 -1.46099889]]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# Example dataset
df = pd.DataFrame({
    'Height':[170,165,180,175,160],
    'Weight':[70,65,80,75,55],
    'Age':[22,25,30,28,19]
})
# Scale
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)
# PCA
pca = PCA(n_components=2)
pca_output = pca.fit_transform(X_scaled)
print("PCA Output:")
print(pca_output[:5])
# ==============================
# 1) Create Simple Target for Classification
#    1 if Weight > 70, else 0
# ==============================
y = (df['Weight'] > 70).astype(int)
# ==============================
# 2) Train/Test Split
# ==============================
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)
# ==============================
# 3) Train Classifier
# ==============================
model = RandomForestClassifier()
model.fit(X_train, y_train)
# =============================
# 4) Predictions + Confusion Matrix
# ==============================
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(cm)               # Screenshot here
# ==============================
# 5) Plot Confusion Matrix (Heatmap)
# ==============================
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# PCA Output:
# [[-3.30185000e-01 -6.23081001e-01]
#  [-6.55389872e-01  5.18157548e-01]
#  [ 2.31104660e+00  7.38573054e-04]
#  [ 1.27483392e+00  1.04014025e-01]
#  [-2.60030565e+00  1.70854852e-04]]
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Confusion Matrix:
# [[1]]

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(cm)
plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# Confusion Matrix:
# [[1]]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
plt.scatter(pca_output[:,0], pca_output[:,1], color='blue')
plt.title("PCA Scatter Plot")
plt.xlabel("Principal Component 1 (PC1)")
plt.ylabel("Principal Component 2 (PC2)")
plt.grid(True)
plt.show()
